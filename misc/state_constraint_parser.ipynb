# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re, copy, itertools, z3, time, sys, pprint

# %%
from action import Action
from PDDLz3 import PDDL_Parser_z3, compile_expression, condition2expression, extract_typed_objects
from collections import OrderedDict
from typing import List, Tuple, Dict, Iterable
from skill_classes import EffectTypePDDL, SkillPDDL
from utils import product_dict, nested_list_replace, get_atoms, get_all_objects, condition_str2objects
from scoping import scope

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
pp = pprint.PrettyPrinter(indent=4)

# %%
33
# Out:
# 33

# %%
constraint_s = """(
	forall (?t - taxi ?p0, ?p1 - passenger) 
	(not
		(and
			(
    			(in-taxi ?p0) (in-taxi ?p1) (not (?p0 = ?p1))
    		)
    	)
    )
)"""

# %%
def parse_tokens2(my_str):
    stack = []
    l2 = []
    for t in re.findall(r'[()]|[^\s()]+', my_str):
        if t == '(':
            stack.append(l2)
            l2 = []
        elif t == ')':
            if stack:
                l = l2
                l2 = stack.pop()
                l2.append(l)
            else:
                raise Exception('Missing open parentheses')
        else:
            l2.append(t)
    if stack:
        raise Exception('Missing close parentheses')
    if len(l2) != 1:
        raise Exception('Malformed expression')
    return l2[0]
def split_predicates2(group):
    pos = []
    neg = []
    if not type(group) is list:
        raise Exception('Error with ')
    if group == []:
        # pass
        return
        # from IPython import embed; embed()
    if group[0] == 'and':
        group.pop(0)
    else:
        group = [group]
    for predicate in group:
        if predicate[0] == 'not':
            if len(predicate) != 2:
                raise Exception('Unexpected not in ')
            neg.append(predicate[-1])
        else:
            pos.append(predicate)
    return pos, neg

# %%
tokens = parse_tokens2(constraint_s)
pp.pprint(tokens)
pos, neg = split_predicates2(tokens)
pp.pprint(pos)
# Out:
# [   'forall',
#     ['?t', '-', 'taxi', '?p0,', '?p1', '-', 'passenger'],
#     [   'not',
#         [   'and',
#             [   ['in-taxi', '?p0'],
#                 ['in-taxi', '?p1'],
#                 ['not', ['?p0', '=', '?p1']]]]]]
# [   [   'forall',
#         ['?t', '-', 'taxi', '?p0,', '?p1', '-', 'passenger'],
#         [   'not',
#             [   'and',
#                 [   ['in-taxi', '?p0'],
#                     ['in-taxi', '?p1'],
#                     ['not', ['?p0', '=', '?p1']]]]]]]

# %%
domain, problem = "domains/taxi-state-constraint/taxi-domain.pddl", "domains/taxi-state-constraint/prob-02.pddl"

parser = PDDL_Parser_z3()
parser.parse_domain(domain)
parser.parse_problem(problem)

# %%
compile_expression(pos[0], parser.make_str2var_dict(), parser)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-13f5585f3860> in <module>
# ----> 1 compile_expression(pos[0], parser.make_str2var_dict(), parser)
#
# ~/repos/scoping/OO-Scoping-IPC/PDDLz3.py in compile_expression(expr, str_var_dict, parser)
#     189
#     190                 # Compile the grounded subexpressions
# --> 191                 compiled_subexpressions = [compile_expression(x, str_var_dict, parser) for x in subexpr_groundings]
#     192                 # Combine the compiled subexpressions
#     193                 combinator = {"forall":z3.And, "exists":z3.Or}[quantifier]
#
# ~/repos/scoping/OO-Scoping-IPC/PDDLz3.py in <listcomp>(.0)
#     189
#     190                 # Compile the grounded subexpressions
# --> 191                 compiled_subexpressions = [compile_expression(x, str_var_dict, parser) for x in subexpr_groundings]
#     192                 # Combine the compiled subexpressions
#     193                 combinator = {"forall":z3.And, "exists":z3.Or}[quantifier]
#
# ~/repos/scoping/OO-Scoping-IPC/PDDLz3.py in compile_expression(expr, str_var_dict, parser)
#     166             # The only length 2 expression we can compile is ['not', [subexpression]]
#     167             if expr[0] == "not":
# --> 168                 return z3.Not(compile_expression(expr[1], str_var_dict, parser))
#     169             else:
#     170                 raise ValueError(f"Don't understand how to compile: {expr}")
#
# ~/repos/scoping/OO-Scoping-IPC/PDDLz3.py in compile_expression(expr, str_var_dict, parser)
#     168                 return z3.Not(compile_expression(expr[1], str_var_dict, parser))
#     169             else:
# --> 170                 raise ValueError(f"Don't understand how to compile: {expr}")
#     171         else:
#     172             # assert len(expr) == 3, f"Don't understand how to compile: {expr}"
#
# ValueError: Don't understand how to compile: ['and', [['in-taxi', '?p0'], ['in-taxi', 'curly'], ['not', ['?p0', '=', 'curly']]]]

# %%
constraint_expr = condition2expression(constraint_s, parser)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-edaa87db55f2> in <module>
# ----> 1 constraint_expr = condition2expression(constraint_s, parser)
#
# NameError: name 'condition2expression' is not defined

# %%
print(pos[0][1])
extract_typed_objects(pos[0][1])
# Out:
# ['?t', '-', 'taxi', '?p0,', '?p1', '-', 'passenger']
# OrderedDict([('?t', 'taxi'), ('?p0,', 'passenger'), ('?p1', 'passenger')])
